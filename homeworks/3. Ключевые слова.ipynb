# %% [markdown]
# В текущем задании мы продолжим работу с анализом и обработкой текстов: проведение частотного анализа, применение метода TF-IDF и выполнение морфологического анализа. Для выполнения вам потребуется текст первых 10 глав романа Л.Н. Толстого "Война и мир" с прошлого домашнего задания.

# %% [markdown]
# Задание 1. Возьмите за основу код из прошлого домашнего задания, проведите нормализацию и предобработку (с токенизацией, настройкой регистра, удалением стоп-слов, заменой иностранных слов на "чтотонафранцузском"). Выполните частотный анализ текста:
#
# 1.   Вывести список топ-20 частотных слов;
# 2.   Вывести топ-20 слов по метрике TF-IDF;
# 3. Вывести абсолютную частотность и значимость метрики TF-IDF для "чтотонафранцузском";
# 4. Проведите морфологический анализ текста (любым пакетом для морф. анализа), извлеките из текста леммы, повторите шаги 1, 2 и 3 на лемматизированном тексте;

# %% [markdown]
# Задание 2.
# Также используя код из предыдущего задания, разделите текст по главам и выполните шаги 1-3 из Задания 1 для каждой из них.

# %% [markdown]
# Задание 3. Отобразите топ 20 существительных, топ 20 прилагательных и топ 20 глаголов по абсолютной частотности и по метрике TF-IDF на материале а) всего текста б) каждой главы.
